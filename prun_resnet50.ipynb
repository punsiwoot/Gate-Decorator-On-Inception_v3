# %%
#import estential tools
import torch
import torchvision
from torchvision import transforms
import torch.nn as nn
import numpy as np
import torch.optim as optim
import os
from prune.universal import Meltable, GatedBatchNorm2d, Conv2dObserver, IterRecoverFramework, FinalLinearObserver
from prune.utils import analyse_model, finetune
from utils import *
from trainer import *

import json 
from config import cfg

# %%
set_seeds()
pack = recover_pack()
# Out:
# ==> Preparing ImageNette data..
# c:\Users\User\AppData\Local\Programs\Python\Python39\lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# c:\Users\User\AppData\Local\Programs\Python\Python39\lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# c:\Users\User\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\optim\lr_scheduler.py:143: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   warnings.warn("Detected call of `lr_scheduler.step()` before `optimizer.step()`. "
# c:\Users\User\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\optim\lr_scheduler.py:156: UserWarning: The epoch parameter in `scheduler.step()` was not necessary and is being deprecated where possible. Please use `scheduler.step()` to step the scheduler. During the deprecation, if epoch is different from None, the closed form is used instead of the new chainable form, where available. Please open an issue if you are unable to replicate your use case: https://github.com/pytorch/pytorch/issues/new/choose.
#   warnings.warn(EPOCH_DEPRECATION_WARNING, UserWarning)
# c:\Users\User\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\optim\lr_scheduler.py:271: UserWarning: To get the last learning rate computed by the scheduler, please use `get_last_lr()`.
#   warnings.warn("To get the last learning rate computed by the scheduler, "

# %%
GBNs = GatedBatchNorm2d.transform(pack.net)
for gbn in GBNs:
    gbn.extract_from_bn()

# %%
pack.net
# Out:
# DataParallel(
#   (module): Resnet50(
#     (backbone): ResNet(
#       (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#       (bn1): GatedBatchNorm2d(
#         64 -> 64 | ID: a032fe4d-eb76-11ee-b60b-fc34974a25ab
#         (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#       (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#       (layer1): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): GatedBatchNorm2d(
#             64 -> 64 | ID: a0332561-eb76-11ee-98a7-fc34974a25ab
#             (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): GatedBatchNorm2d(
#             64 -> 64 | ID: a0332562-eb76-11ee-b082-fc34974a25ab
#             (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): GatedBatchNorm2d(
#             256 -> 256 | ID: a0332563-eb76-11ee-b8f9-fc34974a25ab
#             (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (relu): ReLU(inplace=True)
#           (downsample): Sequential(
#             (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): GatedBatchNorm2d(
#               256 -> 256 | ID: a0332564-eb76-11ee-9aea-fc34974a25ab
#               (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#         )
#         (1): Bottleneck(
#           (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): GatedBatchNorm2d(
#             64 -> 64 | ID: a0332565-eb76-11ee-8297-fc34974a25ab
#             (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): GatedBatchNorm2d(
#             64 -> 64 | ID: a0332566-eb76-11ee-9092-fc34974a25ab
#             (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): GatedBatchNorm2d(
#             256 -> 256 | ID: a0334c6c-eb76-11ee-bdca-fc34974a25ab
#             (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (relu): ReLU(inplace=True)
#         )
#         (2): Bottleneck(
#           (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): GatedBatchNorm2d(
#             64 -> 64 | ID: a0334c6d-eb76-11ee-a0b8-fc34974a25ab
#             (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): GatedBatchNorm2d(
#             64 -> 64 | ID: a0334c6e-eb76-11ee-9f19-fc34974a25ab
#             (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): GatedBatchNorm2d(
#             256 -> 256 | ID: a0334c6f-eb76-11ee-99ea-fc34974a25ab
#             (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (layer2): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): GatedBatchNorm2d(
#             128 -> 128 | ID: a0334c70-eb76-11ee-bac4-fc34974a25ab
#             (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn2): GatedBatchNorm2d(
#             128 -> 128 | ID: a0334c71-eb76-11ee-b229-fc34974a25ab
#             (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): GatedBatchNorm2d(
#             512 -> 512 | ID: a033737d-eb76-11ee-b51c-fc34974a25ab
#             (bn): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (relu): ReLU(inplace=True)
#           (downsample): Sequential(
#             (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): GatedBatchNorm2d(
#               512 -> 512 | ID: a033737e-eb76-11ee-9369-fc34974a25ab
#               (bn): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#         )
#         (1): Bottleneck(
#           (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): GatedBatchNorm2d(
#             128 -> 128 | ID: a033737f-eb76-11ee-bdf0-fc34974a25ab
#             (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): GatedBatchNorm2d(
#             128 -> 128 | ID: a0337380-eb76-11ee-9e80-fc34974a25ab
#             (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): GatedBatchNorm2d(
#             512 -> 512 | ID: a0337381-eb76-11ee-96ea-fc34974a25ab
#             (bn): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (relu): ReLU(inplace=True)
#         )
#         (2): Bottleneck(
#           (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): GatedBatchNorm2d(
#             128 -> 128 | ID: a0337382-eb76-11ee-a556-fc34974a25ab
#             (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): GatedBatchNorm2d(
#             128 -> 128 | ID: a0337383-eb76-11ee-b910-fc34974a25ab
#             (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): GatedBatchNorm2d(
#             512 -> 512 | ID: a0337384-eb76-11ee-ba1e-fc34974a25ab
#             (bn): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (relu): ReLU(inplace=True)
#         )
#         (3): Bottleneck(
#           (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): GatedBatchNorm2d(
#             128 -> 128 | ID: a0337385-eb76-11ee-8dfa-fc34974a25ab
#             (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): GatedBatchNorm2d(
#             128 -> 128 | ID: a0337386-eb76-11ee-a04c-fc34974a25ab
#             (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): GatedBatchNorm2d(
#             512 -> 512 | ID: a0337387-eb76-11ee-88e9-fc34974a25ab
#             (bn): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (layer3): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): GatedBatchNorm2d(
#             256 -> 256 | ID: a0339a89-eb76-11ee-9209-fc34974a25ab
#             (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn2): GatedBatchNorm2d(
#             256 -> 256 | ID: a0339a8a-eb76-11ee-88f1-fc34974a25ab
#             (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): GatedBatchNorm2d(
#             1024 -> 1024 | ID: a0339a8b-eb76-11ee-b05f-fc34974a25ab
#             (bn): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (relu): ReLU(inplace=True)
#           (downsample): Sequential(
#             (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): GatedBatchNorm2d(
#               1024 -> 1024 | ID: a0339a8c-eb76-11ee-8611-fc34974a25ab
#               (bn): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#         )
#         (1): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): GatedBatchNorm2d(
#             256 -> 256 | ID: a0339a8d-eb76-11ee-a793-fc34974a25ab
#             (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): GatedBatchNorm2d(
#             256 -> 256 | ID: a0339a8e-eb76-11ee-b329-fc34974a25ab
#             (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): GatedBatchNorm2d(
#             1024 -> 1024 | ID: a0339a8f-eb76-11ee-9008-fc34974a25ab
#             (bn): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (relu): ReLU(inplace=True)
#         )
#         (2): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): GatedBatchNorm2d(
#             256 -> 256 | ID: a0339a90-eb76-11ee-bf2f-fc34974a25ab
#             (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): GatedBatchNorm2d(
#             256 -> 256 | ID: a0339a91-eb76-11ee-ba39-fc34974a25ab
#             (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): GatedBatchNorm2d(
#             1024 -> 1024 | ID: a0339a92-eb76-11ee-a215-fc34974a25ab
#             (bn): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (relu): ReLU(inplace=True)
#         )
#         (3): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): GatedBatchNorm2d(
#             256 -> 256 | ID: a033c198-eb76-11ee-bee5-fc34974a25ab
#             (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): GatedBatchNorm2d(
#             256 -> 256 | ID: a033c199-eb76-11ee-ad21-fc34974a25ab
#             (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): GatedBatchNorm2d(
#             1024 -> 1024 | ID: a033c19a-eb76-11ee-b3da-fc34974a25ab
#             (bn): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (relu): ReLU(inplace=True)
#         )
#         (4): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): GatedBatchNorm2d(
#             256 -> 256 | ID: a033c19b-eb76-11ee-a685-fc34974a25ab
#             (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): GatedBatchNorm2d(
#             256 -> 256 | ID: a033c19c-eb76-11ee-b9bd-fc34974a25ab
#             (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): GatedBatchNorm2d(
#             1024 -> 1024 | ID: a033c19d-eb76-11ee-8967-fc34974a25ab
#             (bn): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (relu): ReLU(inplace=True)
#         )
#         (5): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): GatedBatchNorm2d(
#             256 -> 256 | ID: a033c19e-eb76-11ee-93d9-fc34974a25ab
#             (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): GatedBatchNorm2d(
#             256 -> 256 | ID: a033c19f-eb76-11ee-8652-fc34974a25ab
#             (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): GatedBatchNorm2d(
#             1024 -> 1024 | ID: a033c1a0-eb76-11ee-aeb5-fc34974a25ab
#             (bn): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (layer4): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): GatedBatchNorm2d(
#             512 -> 512 | ID: a0352135-eb76-11ee-84b8-fc34974a25ab
#             (bn): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn2): GatedBatchNorm2d(
#             512 -> 512 | ID: a0352136-eb76-11ee-b986-fc34974a25ab
#             (bn): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): GatedBatchNorm2d(
#             2048 -> 2048 | ID: a0352137-eb76-11ee-b66e-fc34974a25ab
#             (bn): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (relu): ReLU(inplace=True)
#           (downsample): Sequential(
#             (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): GatedBatchNorm2d(
#               2048 -> 2048 | ID: a0352138-eb76-11ee-abc6-fc34974a25ab
#               (bn): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#         )
#         (1): Bottleneck(
#           (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): GatedBatchNorm2d(
#             512 -> 512 | ID: a0352139-eb76-11ee-9521-fc34974a25ab
#             (bn): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): GatedBatchNorm2d(
#             512 -> 512 | ID: a0354844-eb76-11ee-9e37-fc34974a25ab
#             (bn): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): GatedBatchNorm2d(
#             2048 -> 2048 | ID: a0354845-eb76-11ee-a3d3-fc34974a25ab
#             (bn): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (relu): ReLU(inplace=True)
#         )
#         (2): Bottleneck(
#           (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): GatedBatchNorm2d(
#             512 -> 512 | ID: a0354846-eb76-11ee-8671-fc34974a25ab
#             (bn): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): GatedBatchNorm2d(
#             512 -> 512 | ID: a0354847-eb76-11ee-96a4-fc34974a25ab
#             (bn): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): GatedBatchNorm2d(
#             2048 -> 2048 | ID: a0354848-eb76-11ee-9bc9-fc34974a25ab
#             (bn): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#       (fc): Linear(in_features=2048, out_features=10, bias=True)
#     )
#   )
# )

# %%
import uuid
def bottleneck_set_group(net):
    layers = [
        net.module.backbone.layer1,
        net.module.backbone.layer2,
        net.module.backbone.layer3,
        net.module.backbone.layer4
    ]
    for m in layers:
        masks = []
        for mm in m.modules():
            if mm.__class__.__name__ == 'Bottleneck':
                if mm.downsample is not None:
                    masks.append(mm.downsample._modules['1'])
                masks.append(mm.bn3)

        group_id = uuid.uuid1()
        for mk in masks:
            mk.set_groupid(group_id)

bottleneck_set_group(pack.net)

# %%
pack.net.module.backbone.layer1
# Out:
# Sequential(
#   (0): Bottleneck(
#     (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn1): GatedBatchNorm2d(
#       64 -> 64 | ID: a0332561-eb76-11ee-98a7-fc34974a25ab
#       (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn2): GatedBatchNorm2d(
#       64 -> 64 | ID: a0332562-eb76-11ee-b082-fc34974a25ab
#       (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn3): GatedBatchNorm2d(
#       256 -> 256 | ID: 91ab9a8d-eb81-11ee-bbb3-fc34974a25ab
#       (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (relu): ReLU(inplace=True)
#     (downsample): Sequential(
#       (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): GatedBatchNorm2d(
#         256 -> 256 | ID: 91ab9a8d-eb81-11ee-bbb3-fc34974a25ab
#         (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (1): Bottleneck(
#     (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn1): GatedBatchNorm2d(
#       64 -> 64 | ID: a0332565-eb76-11ee-8297-fc34974a25ab
#       (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn2): GatedBatchNorm2d(
#       64 -> 64 | ID: a0332566-eb76-11ee-9092-fc34974a25ab
#       (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn3): GatedBatchNorm2d(
#       256 -> 256 | ID: 91ab9a8d-eb81-11ee-bbb3-fc34974a25ab
#       (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (relu): ReLU(inplace=True)
#   )
#   (2): Bottleneck(
#     (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn1): GatedBatchNorm2d(
#       64 -> 64 | ID: a0334c6d-eb76-11ee-a0b8-fc34974a25ab
#       (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn2): GatedBatchNorm2d(
#       64 -> 64 | ID: a0334c6e-eb76-11ee-9f19-fc34974a25ab
#       (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn3): GatedBatchNorm2d(
#       256 -> 256 | ID: 91ab9a8d-eb81-11ee-bbb3-fc34974a25ab
#       (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (relu): ReLU(inplace=True)
#   )
# )

# %%
'''
Properly implemented ResNet-s for CIFAR10 as described in paper [1].
The implementation and structure of this file is hugely influenced by [2]
which is implemented for ImageNet and doesn't have option A for identity.
Moreover, most of the implementations on the web is copy-paste from
torchvision's resnet and has wrong number of params.
Proper ResNet-s for CIFAR10 (for fair comparision and etc.) has following
number of layers and parameters:
name      | layers | params
ResNet20  |    20  | 0.27M
ResNet32  |    32  | 0.46M
ResNet44  |    44  | 0.66M
ResNet56  |    56  | 0.85M
ResNet110 |   110  |  1.7M
ResNet1202|  1202  | 19.4m
which this implementation indeed has.
Reference:
[1] Kaiming He, Xiangyu Zhang, Shaoqing Ren, Jian Sun
    Deep Residual Learning for Image Recognition. arXiv:1512.03385
[2] https://github.com/pytorch/vision/blob/master/torchvision/models/resnet.py
If you use this implementation in you work, please don't forget to mention the
author, Yerlan Idelbayev.
'''
import torch
import torch.nn as nn
import torch.nn.init as init

from torch.autograd import Variable

__all__ = ['ResNet', 'resnet20', 'resnet32', 'resnet44', 'resnet56', 'resnet110', 'resnet1202']

def _weights_init(m):
    if isinstance(m, nn.Linear) or isinstance(m, nn.Conv2d):
        init.kaiming_normal(m.weight)

class LambdaLayer(nn.Module):
    def __init__(self, lambd):
        super(LambdaLayer, self).__init__()
        self.lambd = lambd

    def forward(self, x):
        return self.lambd(x)


class BasicBlock(nn.Module):
    expansion = 1

    def __init__(self, in_planes, planes, stride=1, option='B'):
        super(BasicBlock, self).__init__()
        self.conv1 = nn.Conv2d(in_planes, planes, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(planes)
        self.relu = nn.ReLU(inplace=True)
        self.conv2 = nn.Conv2d(planes, planes, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(planes)

        self.shortcut = nn.Sequential()
        if stride != 1 or in_planes != planes:
            if option == 'A':
                self.shortcut = LambdaLayer(lambda x:
                                            F.pad(x[:, :, ::2, ::2], (0, 0, 0, 0, planes//4, planes//4), "constant", 0))
            elif option == 'B':
                self.shortcut = nn.Sequential(
                     nn.Conv2d(in_planes, self.expansion * planes, kernel_size=1, stride=stride, bias=False),
                     nn.BatchNorm2d(self.expansion * planes)
                )

    def forward(self, x):
        out = self.relu(self.bn1(self.conv1(x)))
        out = self.bn2(self.conv2(out))
        out += self.shortcut(x)
        out = self.relu(out)
        return out


class ResNet(nn.Module):
    def __init__(self, block, num_blocks, num_classes=10):
        super(ResNet, self).__init__()
        self.in_planes = 16

        self.conv1 = nn.Conv2d(3, 16, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(16)
        self.layer1 = self._make_layer(block, 16, num_blocks[0], stride=1)
        self.layer2 = self._make_layer(block, 32, num_blocks[1], stride=2)
        self.layer3 = self._make_layer(block, 64, num_blocks[2], stride=2)
        self.linear = nn.Linear(64, num_classes)

        self.avgpool = nn.AdaptiveAvgPool2d((1, 1))
        self.relu = nn.ReLU(inplace=True)

        self.apply(_weights_init)

    def _make_layer(self, block, planes, num_blocks, stride):
        strides = [stride] + [1]*(num_blocks-1)
        layers = []
        for stride in strides:
            layers.append(block(self.in_planes, planes, stride))
            self.in_planes = planes * block.expansion

        return nn.Sequential(*layers)

    def forward(self, x):
        out = self.relu(self.bn1(self.conv1(x)))
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.avgpool(out)
        out = out.view(out.size(0), -1)
        out = self.linear(out)
        return out


def resnet20(num_classes):
    return ResNet(BasicBlock, [3, 3, 3], num_classes)


def resnet32(num_classes):
    return ResNet(BasicBlock, [5, 5, 5], num_classes)


def resnet44(num_classes):
    return ResNet(BasicBlock, [7, 7, 7], num_classes)


def resnet56(num_classes):
    return ResNet(BasicBlock, [9, 9, 9], num_classes)


def resnet110(num_classes):
    return ResNet(BasicBlock, [18, 18, 18], num_classes)


def resnet1202(num_classes):
    return ResNet(BasicBlock, [200, 200, 200], num_classes)

# %%
model = resnet56(10)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_19804\1418736441.py:34: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   init.kaiming_normal(m.weight)

# %%
pack.net.module
# Out:
# Resnet50(
#   (backbone): ResNet(
#     (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (bn1): GatedBatchNorm2d(
#       64 -> 64 | ID: a032fe4d-eb76-11ee-b60b-fc34974a25ab
#       (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (relu): ReLU(inplace=True)
#     (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (layer1): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): GatedBatchNorm2d(
#           64 -> 64 | ID: a0332561-eb76-11ee-98a7-fc34974a25ab
#           (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): GatedBatchNorm2d(
#           64 -> 64 | ID: a0332562-eb76-11ee-b082-fc34974a25ab
#           (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): GatedBatchNorm2d(
#           256 -> 256 | ID: a0332563-eb76-11ee-b8f9-fc34974a25ab
#           (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): GatedBatchNorm2d(
#             256 -> 256 | ID: a0332564-eb76-11ee-9aea-fc34974a25ab
#             (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): GatedBatchNorm2d(
#           64 -> 64 | ID: a0332565-eb76-11ee-8297-fc34974a25ab
#           (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): GatedBatchNorm2d(
#           64 -> 64 | ID: a0332566-eb76-11ee-9092-fc34974a25ab
#           (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): GatedBatchNorm2d(
#           256 -> 256 | ID: a0334c6c-eb76-11ee-bdca-fc34974a25ab
#           (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): GatedBatchNorm2d(
#           64 -> 64 | ID: a0334c6d-eb76-11ee-a0b8-fc34974a25ab
#           (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): GatedBatchNorm2d(
#           64 -> 64 | ID: a0334c6e-eb76-11ee-9f19-fc34974a25ab
#           (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): GatedBatchNorm2d(
#           256 -> 256 | ID: a0334c6f-eb76-11ee-99ea-fc34974a25ab
#           (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (layer2): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): GatedBatchNorm2d(
#           128 -> 128 | ID: a0334c70-eb76-11ee-bac4-fc34974a25ab
#           (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn2): GatedBatchNorm2d(
#           128 -> 128 | ID: a0334c71-eb76-11ee-b229-fc34974a25ab
#           (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): GatedBatchNorm2d(
#           512 -> 512 | ID: a033737d-eb76-11ee-b51c-fc34974a25ab
#           (bn): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): GatedBatchNorm2d(
#             512 -> 512 | ID: a033737e-eb76-11ee-9369-fc34974a25ab
#             (bn): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): GatedBatchNorm2d(
#           128 -> 128 | ID: a033737f-eb76-11ee-bdf0-fc34974a25ab
#           (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): GatedBatchNorm2d(
#           128 -> 128 | ID: a0337380-eb76-11ee-9e80-fc34974a25ab
#           (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): GatedBatchNorm2d(
#           512 -> 512 | ID: a0337381-eb76-11ee-96ea-fc34974a25ab
#           (bn): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): GatedBatchNorm2d(
#           128 -> 128 | ID: a0337382-eb76-11ee-a556-fc34974a25ab
#           (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): GatedBatchNorm2d(
#           128 -> 128 | ID: a0337383-eb76-11ee-b910-fc34974a25ab
#           (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): GatedBatchNorm2d(
#           512 -> 512 | ID: a0337384-eb76-11ee-ba1e-fc34974a25ab
#           (bn): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (relu): ReLU(inplace=True)
#       )
#       (3): Bottleneck(
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): GatedBatchNorm2d(
#           128 -> 128 | ID: a0337385-eb76-11ee-8dfa-fc34974a25ab
#           (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): GatedBatchNorm2d(
#           128 -> 128 | ID: a0337386-eb76-11ee-a04c-fc34974a25ab
#           (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): GatedBatchNorm2d(
#           512 -> 512 | ID: a0337387-eb76-11ee-88e9-fc34974a25ab
#           (bn): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (layer3): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): GatedBatchNorm2d(
#           256 -> 256 | ID: a0339a89-eb76-11ee-9209-fc34974a25ab
#           (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn2): GatedBatchNorm2d(
#           256 -> 256 | ID: a0339a8a-eb76-11ee-88f1-fc34974a25ab
#           (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): GatedBatchNorm2d(
#           1024 -> 1024 | ID: a0339a8b-eb76-11ee-b05f-fc34974a25ab
#           (bn): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): GatedBatchNorm2d(
#             1024 -> 1024 | ID: a0339a8c-eb76-11ee-8611-fc34974a25ab
#             (bn): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): GatedBatchNorm2d(
#           256 -> 256 | ID: a0339a8d-eb76-11ee-a793-fc34974a25ab
#           (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): GatedBatchNorm2d(
#           256 -> 256 | ID: a0339a8e-eb76-11ee-b329-fc34974a25ab
#           (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): GatedBatchNorm2d(
#           1024 -> 1024 | ID: a0339a8f-eb76-11ee-9008-fc34974a25ab
#           (bn): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): GatedBatchNorm2d(
#           256 -> 256 | ID: a0339a90-eb76-11ee-bf2f-fc34974a25ab
#           (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): GatedBatchNorm2d(
#           256 -> 256 | ID: a0339a91-eb76-11ee-ba39-fc34974a25ab
#           (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): GatedBatchNorm2d(
#           1024 -> 1024 | ID: a0339a92-eb76-11ee-a215-fc34974a25ab
#           (bn): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (relu): ReLU(inplace=True)
#       )
#       (3): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): GatedBatchNorm2d(
#           256 -> 256 | ID: a033c198-eb76-11ee-bee5-fc34974a25ab
#           (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): GatedBatchNorm2d(
#           256 -> 256 | ID: a033c199-eb76-11ee-ad21-fc34974a25ab
#           (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): GatedBatchNorm2d(
#           1024 -> 1024 | ID: a033c19a-eb76-11ee-b3da-fc34974a25ab
#           (bn): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (relu): ReLU(inplace=True)
#       )
#       (4): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): GatedBatchNorm2d(
#           256 -> 256 | ID: a033c19b-eb76-11ee-a685-fc34974a25ab
#           (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): GatedBatchNorm2d(
#           256 -> 256 | ID: a033c19c-eb76-11ee-b9bd-fc34974a25ab
#           (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): GatedBatchNorm2d(
#           1024 -> 1024 | ID: a033c19d-eb76-11ee-8967-fc34974a25ab
#           (bn): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (relu): ReLU(inplace=True)
#       )
#       (5): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): GatedBatchNorm2d(
#           256 -> 256 | ID: a033c19e-eb76-11ee-93d9-fc34974a25ab
#           (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): GatedBatchNorm2d(
#           256 -> 256 | ID: a033c19f-eb76-11ee-8652-fc34974a25ab
#           (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): GatedBatchNorm2d(
#           1024 -> 1024 | ID: a033c1a0-eb76-11ee-aeb5-fc34974a25ab
#           (bn): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (layer4): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): GatedBatchNorm2d(
#           512 -> 512 | ID: a0352135-eb76-11ee-84b8-fc34974a25ab
#           (bn): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn2): GatedBatchNorm2d(
#           512 -> 512 | ID: a0352136-eb76-11ee-b986-fc34974a25ab
#           (bn): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): GatedBatchNorm2d(
#           2048 -> 2048 | ID: a0352137-eb76-11ee-b66e-fc34974a25ab
#           (bn): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): GatedBatchNorm2d(
#             2048 -> 2048 | ID: a0352138-eb76-11ee-abc6-fc34974a25ab
#             (bn): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): GatedBatchNorm2d(
#           512 -> 512 | ID: a0352139-eb76-11ee-9521-fc34974a25ab
#           (bn): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): GatedBatchNorm2d(
#           512 -> 512 | ID: a0354844-eb76-11ee-9e37-fc34974a25ab
#           (bn): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): GatedBatchNorm2d(
#           2048 -> 2048 | ID: a0354845-eb76-11ee-a3d3-fc34974a25ab
#           (bn): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): GatedBatchNorm2d(
#           512 -> 512 | ID: a0354846-eb76-11ee-8671-fc34974a25ab
#           (bn): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): GatedBatchNorm2d(
#           512 -> 512 | ID: a0354847-eb76-11ee-96a4-fc34974a25ab
#           (bn): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): GatedBatchNorm2d(
#           2048 -> 2048 | ID: a0354848-eb76-11ee-9bc9-fc34974a25ab
#           (bn): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#     (fc): Linear(in_features=2048, out_features=10, bias=True)
#   )
# )

# %%
GBNs_resnet56 = GatedBatchNorm2d.transform(model)
for gbn in GBNs_resnet56:
    gbn.extract_from_bn()

# %%
model
# Out:
# ResNet(
#   (conv1): Conv2d(3, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (bn1): GatedBatchNorm2d(
#     16 -> 16 | ID: 3aa4cd7c-eb7c-11ee-943c-fc34974a25ab
#     (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): GatedBatchNorm2d(
#         16 -> 16 | ID: 3aa4f40a-eb7c-11ee-a718-fc34974a25ab
#         (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): GatedBatchNorm2d(
#         16 -> 16 | ID: 3aa4f40b-eb7c-11ee-a8fc-fc34974a25ab
#         (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (shortcut): Sequential()
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): GatedBatchNorm2d(
#         16 -> 16 | ID: 3aa51b17-eb7c-11ee-ba6e-fc34974a25ab
#         (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): GatedBatchNorm2d(
#         16 -> 16 | ID: 3aa51b18-eb7c-11ee-8d16-fc34974a25ab
#         (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (shortcut): Sequential()
#     )
#     (2): BasicBlock(
#       (conv1): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): GatedBatchNorm2d(
#         16 -> 16 | ID: 3aa51b19-eb7c-11ee-bddc-fc34974a25ab
#         (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): GatedBatchNorm2d(
#         16 -> 16 | ID: 3aa51b1a-eb7c-11ee-a35c-fc34974a25ab
#         (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (shortcut): Sequential()
#     )
#     (3): BasicBlock(
#       (conv1): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): GatedBatchNorm2d(
#         16 -> 16 | ID: 3aa51b1b-eb7c-11ee-9e87-fc34974a25ab
#         (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): GatedBatchNorm2d(
#         16 -> 16 | ID: 3aa51b1c-eb7c-11ee-9c55-fc34974a25ab
#         (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (shortcut): Sequential()
#     )
#     (4): BasicBlock(
#       (conv1): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): GatedBatchNorm2d(
#         16 -> 16 | ID: 3aa5422e-eb7c-11ee-b761-fc34974a25ab
#         (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): GatedBatchNorm2d(
#         16 -> 16 | ID: 3aa5422f-eb7c-11ee-a15d-fc34974a25ab
#         (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (shortcut): Sequential()
#     )
#     (5): BasicBlock(
#       (conv1): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): GatedBatchNorm2d(
#         16 -> 16 | ID: 3aa54230-eb7c-11ee-90ab-fc34974a25ab
#         (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): GatedBatchNorm2d(
#         16 -> 16 | ID: 3aa54231-eb7c-11ee-83fc-fc34974a25ab
#         (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (shortcut): Sequential()
#     )
#     (6): BasicBlock(
#       (conv1): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): GatedBatchNorm2d(
#         16 -> 16 | ID: 3aa54232-eb7c-11ee-b385-fc34974a25ab
#         (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): GatedBatchNorm2d(
#         16 -> 16 | ID: 3aa54233-eb7c-11ee-bac8-fc34974a25ab
#         (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (shortcut): Sequential()
#     )
#     (7): BasicBlock(
#       (conv1): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): GatedBatchNorm2d(
#         16 -> 16 | ID: 3aa54234-eb7c-11ee-a31d-fc34974a25ab
#         (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): GatedBatchNorm2d(
#         16 -> 16 | ID: 3aa54235-eb7c-11ee-ba9f-fc34974a25ab
#         (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (shortcut): Sequential()
#     )
#     (8): BasicBlock(
#       (conv1): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): GatedBatchNorm2d(
#         16 -> 16 | ID: 3aa56933-eb7c-11ee-80e6-fc34974a25ab
#         (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): GatedBatchNorm2d(
#         16 -> 16 | ID: 3aa56934-eb7c-11ee-85f8-fc34974a25ab
#         (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (shortcut): Sequential()
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(16, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): GatedBatchNorm2d(
#         32 -> 32 | ID: 3aa56935-eb7c-11ee-ae0f-fc34974a25ab
#         (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): GatedBatchNorm2d(
#         32 -> 32 | ID: 3aa56936-eb7c-11ee-b5c4-fc34974a25ab
#         (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (shortcut): Sequential(
#         (0): Conv2d(16, 32, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): GatedBatchNorm2d(
#           32 -> 32 | ID: 3aa56937-eb7c-11ee-9986-fc34974a25ab
#           (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): GatedBatchNorm2d(
#         32 -> 32 | ID: 3aa56938-eb7c-11ee-ad74-fc34974a25ab
#         (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): GatedBatchNorm2d(
#         32 -> 32 | ID: 3aa56939-eb7c-11ee-b4ca-fc34974a25ab
#         (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (shortcut): Sequential()
#     )
#     (2): BasicBlock(
#       (conv1): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): GatedBatchNorm2d(
#         32 -> 32 | ID: 3aa59049-eb7c-11ee-b23e-fc34974a25ab
#         (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): GatedBatchNorm2d(
#         32 -> 32 | ID: 3aa5904a-eb7c-11ee-aac3-fc34974a25ab
#         (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (shortcut): Sequential()
#     )
#     (3): BasicBlock(
#       (conv1): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): GatedBatchNorm2d(
#         32 -> 32 | ID: 3aa5904b-eb7c-11ee-a804-fc34974a25ab
#         (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): GatedBatchNorm2d(
#         32 -> 32 | ID: 3aa5904c-eb7c-11ee-8012-fc34974a25ab
#         (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (shortcut): Sequential()
#     )
#     (4): BasicBlock(
#       (conv1): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): GatedBatchNorm2d(
#         32 -> 32 | ID: 3aa5904d-eb7c-11ee-a729-fc34974a25ab
#         (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): GatedBatchNorm2d(
#         32 -> 32 | ID: 3aa5904e-eb7c-11ee-9f96-fc34974a25ab
#         (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (shortcut): Sequential()
#     )
#     (5): BasicBlock(
#       (conv1): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): GatedBatchNorm2d(
#         32 -> 32 | ID: 3aa5904f-eb7c-11ee-b4fe-fc34974a25ab
#         (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): GatedBatchNorm2d(
#         32 -> 32 | ID: 3aa59050-eb7c-11ee-b786-fc34974a25ab
#         (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (shortcut): Sequential()
#     )
#     (6): BasicBlock(
#       (conv1): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): GatedBatchNorm2d(
#         32 -> 32 | ID: 3aa59051-eb7c-11ee-9552-fc34974a25ab
#         (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): GatedBatchNorm2d(
#         32 -> 32 | ID: 3aa59052-eb7c-11ee-8f9c-fc34974a25ab
#         (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (shortcut): Sequential()
#     )
#     (7): BasicBlock(
#       (conv1): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): GatedBatchNorm2d(
#         32 -> 32 | ID: 3aa59053-eb7c-11ee-aebc-fc34974a25ab
#         (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): GatedBatchNorm2d(
#         32 -> 32 | ID: 3aa59054-eb7c-11ee-94d0-fc34974a25ab
#         (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (shortcut): Sequential()
#     )
#     (8): BasicBlock(
#       (conv1): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): GatedBatchNorm2d(
#         32 -> 32 | ID: 3aa5b758-eb7c-11ee-ad08-fc34974a25ab
#         (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): GatedBatchNorm2d(
#         32 -> 32 | ID: 3aa5b759-eb7c-11ee-b7b5-fc34974a25ab
#         (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (shortcut): Sequential()
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): GatedBatchNorm2d(
#         64 -> 64 | ID: 3aa5b75a-eb7c-11ee-8407-fc34974a25ab
#         (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): GatedBatchNorm2d(
#         64 -> 64 | ID: 3aa5b75b-eb7c-11ee-8c3a-fc34974a25ab
#         (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (shortcut): Sequential(
#         (0): Conv2d(32, 64, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): GatedBatchNorm2d(
#           64 -> 64 | ID: 3aa5b75c-eb7c-11ee-bab0-fc34974a25ab
#           (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): GatedBatchNorm2d(
#         64 -> 64 | ID: 3aa5b75d-eb7c-11ee-a452-fc34974a25ab
#         (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): GatedBatchNorm2d(
#         64 -> 64 | ID: 3aa5b75e-eb7c-11ee-8e30-fc34974a25ab
#         (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (shortcut): Sequential()
#     )
#     (2): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): GatedBatchNorm2d(
#         64 -> 64 | ID: 3aa5de5c-eb7c-11ee-8f45-fc34974a25ab
#         (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): GatedBatchNorm2d(
#         64 -> 64 | ID: 3aa5de5d-eb7c-11ee-b36a-fc34974a25ab
#         (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (shortcut): Sequential()
#     )
#     (3): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): GatedBatchNorm2d(
#         64 -> 64 | ID: 3aa5de5e-eb7c-11ee-bdec-fc34974a25ab
#         (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): GatedBatchNorm2d(
#         64 -> 64 | ID: 3aa5de5f-eb7c-11ee-891e-fc34974a25ab
#         (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (shortcut): Sequential()
#     )
#     (4): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): GatedBatchNorm2d(
#         64 -> 64 | ID: 3aa5de60-eb7c-11ee-b367-fc34974a25ab
#         (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): GatedBatchNorm2d(
#         64 -> 64 | ID: 3aa5de61-eb7c-11ee-a2c0-fc34974a25ab
#         (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (shortcut): Sequential()
#     )
#     (5): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): GatedBatchNorm2d(
#         64 -> 64 | ID: 3aa5de62-eb7c-11ee-9cab-fc34974a25ab
#         (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): GatedBatchNorm2d(
#         64 -> 64 | ID: 3aa5de63-eb7c-11ee-85d6-fc34974a25ab
#         (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (shortcut): Sequential()
#     )
#     (6): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): GatedBatchNorm2d(
#         64 -> 64 | ID: 3aa5de64-eb7c-11ee-8526-fc34974a25ab
#         (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): GatedBatchNorm2d(
#         64 -> 64 | ID: 3aa6056c-eb7c-11ee-bf90-fc34974a25ab
#         (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (shortcut): Sequential()
#     )
#     (7): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): GatedBatchNorm2d(
#         64 -> 64 | ID: 3aa6056d-eb7c-11ee-947b-fc34974a25ab
#         (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): GatedBatchNorm2d(
#         64 -> 64 | ID: 3aa6056e-eb7c-11ee-b801-fc34974a25ab
#         (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (shortcut): Sequential()
#     )
#     (8): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): GatedBatchNorm2d(
#         64 -> 64 | ID: 3aa6056f-eb7c-11ee-a082-fc34974a25ab
#         (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): GatedBatchNorm2d(
#         64 -> 64 | ID: 3aa60570-eb7c-11ee-bfde-fc34974a25ab
#         (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (shortcut): Sequential()
#     )
#   )
#   (linear): Linear(in_features=64, out_features=10, bias=True)
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (relu): ReLU(inplace=True)
# )
